# %% [markdown]
# ## 1) Types of numbers
#
#
# - Integers are just whole numbers, positive or negative.
#
# - Python has various "types" of numbers (numeric literals). that are the `integers` and `floating point numbers`.
#
# - Integers are just whole numbers, positive or negative. **For example: 4 and -5 are examples of integers.**
#
# - Floating point numbers in Python are notable because they have a **decimal point** in them.
#
#
# **Example of floating point number in Python.**
#
# Decimal points(Floating point): **2.5, 5.5, 6.5, 7.55**

# %% [markdown]
# | Examples        |  Number "Data Type"   |
# |-----------------|-----------------------|
# | 4,7,-5,4000     | Integers              |
# |||
# |4.2,-0.5,2e2,3E2 | Floating-point numbers|

# %% [markdown]
# ### Python as basic calculator

# %%
# Addition of two number


print(5+5)
# Out:
# 10

# %%
# Substraction of two numbers

print(10-2)
# Out:
# 8

# %%
# Multiplicaion of two numbers

print(5*5)
# Out:
# 25

# %%
# Division of two numbers

print(20/5)
# Out:
# 4.0

# %%
# Floor division

print(20//5)
# Out:
# 4

# %% [markdown]
# ### Difference between division and floor division
#
# The reason we get this result is because we are using `floor` division. The `**//**` operator (two forward slashes) truncates the decimal without rounding, and returns an integer result.
#
# Division gives the output in Decimal format while floor division gives the output in number format

# %%
# Modulo which can also called as remainder


print(21%2)

# when we divide the number 21 by 2 we get the remainder is 1
# Out:
# 1

# %%
print(30%2)

# Here remainder is 0 when we divide 30 by 2
# Out:
# 0

# %%
# Exponential or powers

# which can also called as cube of 2.
# There are two methods to find cube (2*2*2) and second is (2**3)

print(2*2*2)


print(2**3)
# Out:
# 8
# 8

# %%
# Square root

print(4*0.5)
# Out:
# 2.0

# %%
1/2
# Out:
# 0.5

# %%
print(4*1/2)
# Out:
# 2.0

# %% [markdown]
# ### These are the basic arithmatic methods that can be used in python

# %%
# Basic operators in python


print(4+5*4+5)

# here it will first multiply the values and then add it
# Out:
# 29

# %%
4+20+5
# Out:
# 29

# %%
# Use of brackets 


print((4+5)*(4+5))
# Out:
# 81

# %%
# Here we can see the results first it will solve the brackets and then multiply the values

# %%
n=1_3_455_667

print(n)
# Out:
# 13455667

# %%
type(n)
# Out:
# int

# %%
print(1)
print(type(1))

print(2.34)
print(type(2.34))


a=1  # a is varible inside a we store 1 value
b=3323232322  # b is varible inside a we store 3323232322 value
c=23.32 # c is varible inside a we store 23.32 value
d=-23232 # d is variable inside d we store -2323 value

print(a)
print(b)
print(c)
print(d)

print(type(a))
print(type(b))
print(type(c))
print(type(d))
# Out:
# 1
# <class 'int'>
# 2.34
# <class 'float'>
# 1
# 3323232322
# 23.32
# -23232
# <class 'int'>
# <class 'int'>
# <class 'float'>
# <class 'int'>

# %%
# Casting

x=int(1)
print(x)
print(type(x))


y=3.232 # it is float value
print(y)  #print y variable
print(type(y)) #type of y is float here


z=int(y)  # We had cast float value to int 
print(z)  # print z
print(type(z)) # here we can see the we had chnage data type float to int
# Out:
# 1
# <class 'int'>
# 3.232
# <class 'float'>
# 3
# <class 'int'>

# %%
print(1_2_222_323323)
# Out:
# 12222323323

# %%
# Measure distance
# abs

print(2-6)
print(abs(2-6))  # abs is used to measure distance it will give positive value
# Out:
# -4
# 4

# %%
price=35.5487 
drop=35.4487
print(round(price))  # round to nearest integer  Handy in DA to clean up numbers for reports or save space
print(round(drop))  # round to nearest integer
print(round(price, 2))  # round to 2 decimal places
# Out:
# 36
# 35
# 35.55

# %%
# ROunding numbers


import random
print(random.random())  # it will give random number between 0 to 1
print(random.randint(1,100))
# Out:
# 0.5156403083192078
# 9
