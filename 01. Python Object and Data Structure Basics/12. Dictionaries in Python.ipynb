# %% [markdown]
# # Dictionaries
#
# In List we have Learn about `sequences` in Python but now we are going to learn about `mappings` in Python.
#
# * A `dictionary` is a collection which is unordered, changeable and indexed. In Python dictionaries are written with curly brackets, and they have keys and values
#
#
# * what are **mappings?** Mappings are a collection of objects that are stored by a *key*, unlike a sequence that stored objects by their relative position.
#
# * A Python dictionary consists of a key and then an associated value. That value can be almost any Python object.

# %% [markdown]
# ## Constructing a Dictionary
#
# Creating a dictionary is as simple as placing items inside `curly braces {}` separated by `commas(,)`.

# %%
# Make a dictionary with {} and : to signify a key and a value

my_dict = {'key1':'value1','key2':'value2'}

# %%
print(my_dict)
# Out:
# {'key1': 'value1', 'key2': 'value2'}

# %%
My_dict={"a":10,
"b":20,
"c":30,
"d":40}

print(My_dict)

# thie is out dictionary which is having key value pair
# Out:
# {'a': 10, 'b': 20, 'c': 30, 'd': 40}

# %%
My_dict={"a":10,"b":20,"c":30,"a":40}
print(My_dict)

# see here we can dict does not allow key duplicates
# Out:
# {'a': 40, 'b': 20, 'c': 30}

# %%
My_dict={"a":10,"b":20,"c":30,"d":30}
print(My_dict)

# But here we can see dictionary aollow duplicates values
# Out:
# {'a': 10, 'b': 20, 'c': 30, 'd': 30}

# %%
My_dict={"a":10,"b":20,"c":30,"a":40}
print(My_dict)
print(My_dict['1'])

# dictionaty not aollowed the index
# Out:
# {'a': 40, 'b': 20, 'c': 30}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 3
#       1 My_dict={"a":10,"b":20,"c":30,"a":40}
#       2 print(My_dict)
# ----> 3 print(My_dict['1'])
#       4
#       5 # dictionaty not aollowed the index
#
# KeyError: '1'

# %%
My_dict={"a":10,"b":20,"c":30,"a":40}
print(My_dict)

My_dict['a']=111
print(My_dict)

# see here we can see dictionary are mutable
# Out:
# {'a': 40, 'b': 20, 'c': 30}
# {'a': 111, 'b': 20, 'c': 30}

# %%
# Call values by their key

print(my_dict['key1'])
# Out:
# value1

# %%
print(my_dict['key2'])
# Out:
# value2

# %% [markdown]
# Its important to note that dictionaries are very flexible in the data types they can hold. For example:

# %%
my_dict={'key1':123,'key2':[12,32,2],'key3':['item0','item1','item2']}

# %%
my_dict
# Out:
# {'key1': 123, 'key2': [12, 32, 2], 'key3': ['item0', 'item1', 'item2']}

# %%
#Lets call items from the dictionary

print(my_dict['key3'])
# Out:
# ['item0', 'item1', 'item2']

# %%
# Can call an index on that value

print(my_dict['key3'][1])
# Out:
# item1

# %%
# Can then even call methods on that value

print(my_dict['key3'][1].upper())
# Out:
# ITEM1

# %%
price={'apple':120,'orange':80,'milk':50}

# %%
print(price['milk'])
# Out:
# 50

# %%
user={"id":1,"age":30,"city":"Mumbai"}
print(user)
# Out:
# {'id': 1, 'age': 30, 'city': 'Mumbai'}

# %%
print(user["name"])

# it will throw an error
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 print(user["name"])
#
# KeyError: 'name'

# %%
print(user.get("Name"))

# get method help us to retruns value safely gives None if missing
# Out:
# None

# %%
print(user.get("name","unknown"))
# we can have defualt value as well
# Out:
# unknown

# %%
# checks

user={"id":1,"age":30,"city":"Mumbai"}
print(user)

print("age" in user)
print("name" not in user)
# Out:
# {'id': 1, 'age': 30, 'city': 'Mumbai'}
# True
# True

# %%
# View objects

print(user.keys())  # will get only keys
print(user.values()) # will get only values
print(user.items()) # perfect when you  need key and value together for looping,transforming datA, BUILDING new dicts, comparing and more
# Out:
# dict_keys(['id', 'age', 'city'])
# dict_values([1, 30, 'Mumbai'])
# dict_items([('id', 1), ('age', 30), ('city', 'Mumbai')])

# %%
user={"id":1,"age":30,"city":"Mumbai"}

for i in user:
    print(i,user[i])
# Out:
# id 1
# age 30
# city Mumbai

# %%
for key,value in user.items():
    print(key,value)
# Out:
# id 1
# age 30
# city Mumbai

# %% [markdown]
# We can effect the values of a key as well. For instance:

# %%
price={'apple':120,'orange':80,'milk':50}

price['apple']
# Out:
# 120

# %%
# Subtract 123 from the value

price['apple']-118
# Out:
# 2

# %%
# there will be no permant change in dictionary

price['apple']
# Out:
# 120

# %%
# To make a permant change in the dictionary assign the variable  
# Subtract 117 from the value 

price['apple'] = price['apple']-117

# %%
# check here we can see apple price is 120 so (120-117)

price['apple']
# Out:
# 3

# %%
# check

price
# Out:
# {'apple': 3, 'orange': 80, 'milk': 50}

# %% [markdown]
# A quick note, Python has a built-in method of doing a self subtraction or addition (or multiplication or division). We could have also used `+=` or `-=` for the above statement. For example:

# %%
# Addition 
# here the apple value is 3 we add the value 10 

price['apple']+=10

# %%
# check

price['apple']
# Out:
# 13

# %%
# check output

price
# Out:
# {'apple': 13, 'orange': 80, 'milk': 50}

# %%
# subtraction
# here the apple value is 13 we subtract the value 10 

price['apple']-=10

# %%
#check output

price['apple']
# Out:
# 3

# %%
# multiplication
# here the apple value is 3 we multiply the value 10 

price['apple']*=10

# %%
# check value

price['apple']
# Out:
# 30

# %%
# create a dictionary

dict={'k1':110,'k2':"string",'k3':20.5}

# %%
dict
# Out:
# {'k1': 110, 'k2': 'string', 'k3': 20.5}

# %%
# grabs the first key which is k1

dict['k1']
# Out:
# 110

# %%
# grabs the second key which is k2

dict['k2']
# Out:
# 'string'

# %%
# grabs the second key first index which is 's`

dict['k2'][0]
# Out:
# 's'

# %%
# grabs the second key index from o to 3

dict['k2'][0:3]
# Out:
# 'str'

# %%
dict['k2'][:3]
# Out:
# 'str'

# %%
# gives the revers index

dict['k2'][::-1]
# Out:
# 'gnirts'

# %%
dict['k2'][2:]
# Out:
# 'ring'

# %%
# delete the second key

del dict['k2']

# %%
dict
# Out:
# {'k1': 110, 'k3': 20.5}

# %%
# add,remove,update


# add
user={"id":1,"name":"bob","age":22}
print(user)

user["city"]="berlin"
print(user)
# Out:
# {'id': 1, 'name': 'bob', 'age': 22}
# {'id': 1, 'name': 'bob', 'age': 22, 'city': 'berlin'}

# %%
# update

user["age"]=44
print(user)

user.update({"age":38,"city":"Paris"})  # updating multiple values
print(user)
# Out:
# {'id': 1, 'name': 'bob', 'age': 44, 'city': 'berlin'}
# {'id': 1, 'name': 'bob', 'age': 38, 'city': 'Paris'}

# %%
# Remove

user.pop(1)
# as dictionary not aollowed to use index so we cna define key here
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[67], line 3
#       1 # Remove
#       2
# ----> 3 user.pop(1)
#       4 # as dictionary not aollowed to use index so we cna define key here
#
# KeyError: 1

# %%
user={"id":1,"name":"bob","age":22}
user.pop("age")
print(user)
# Out:
# {'id': 1, 'name': 'bob'}

# %%
user={"id":1,"name":"bob","age":22}

age=user.pop("age")
print(user)
print("Removed value:",age)

salary=user.pop("salary","Not found")
print("Removed value:",salary)

# supose we don not have salary value and we had use in pop so what we can do is we can set default not found
# Out:
# {'id': 1, 'name': 'bob'}
# Removed value: 22
# Removed value: Not found

# %%
user={"id":None,"name":None,"age":None,"salary":None}
print(user)


user=dict.fromkeys(["id","name","age","salary"],0)
print(user)

user["age"]=40
print(user)
# Out:
# {'id': None, 'name': None, 'age': None, 'salary': None}
# {'id': 0, 'name': 0, 'age': 0, 'salary': 0}
# {'id': 0, 'name': 0, 'age': 40, 'salary': 0}

# %%
user={"id":1,"name":"bob","age":23,"salary":122,"city":"Berlin"}
print(user)

new_dict={}
# input {"id":1,"name":"bob","age":23,"salary":122,"city":"Berlin"}
# output: "name":"bob","city":"Berlin"


new_dict={
    key:value.upper()
    for key,value in user.items()
    if isinstance(value, str)
}
print(new_dict)
# Out:
# {'id': 1, 'name': 'bob', 'age': 23, 'salary': 122, 'city': 'Berlin'}
# {'name': 'BOB', 'city': 'BERLIN'}

# %% [markdown]
# We can also create keys by assignment. For instance if we started off with an empty dictionary, we could continually add to it:

# %%
# Create a new dictionary

s = {}

# %%
# Create a new key through assignment

s['animal'] = 'Dog'

# %%
# create a another key with any object

s['answer'] = 42

# %%
# show

s
# Out:
# {'animal': 'Dog', 'answer': 42}

# %%
list(s)
# Out:
# ['animal', 'answer']

# %% [markdown]
# ## Nesting with Dictionaries
#
# Let's see a dictionary nested inside a dictionary:

# %%
# Dictionary nested inside a dictionary nested inside a dictionary

dict={"key":{'nestkey':{'subnestkey':'value'}}}

# %%
# calling dict

dict
# Out:
# {'key': {'nestkey': {'subnestkey': 'value'}}}

# %%
# calling the keys

dict['key']
# Out:
# {'nestkey': {'subnestkey': 'value'}}

# %%
# calling the nestkey

dict['key']['nestkey']
# Out:
# {'subnestkey': 'value'}

# %%
# calling the subnestkey

dict['key']['nestkey']['subnestkey']
# Out:
# 'value'

# %%
dict['key']['nestkey']['subnestkey'].upper()
# Out:
# 'VALUE'

# %% [markdown]
# ## A few Dictionary Methods
#
# There are a few methods we can call on a dictionary.

# %%
# Create a typical dictionary

d={}

# %%
d['k1']=1

# %%
d['k2']=2

# %%
d['k3']=3

# %%
d
# Out:
# {'k1': 1, 'k2': 2, 'k3': 3}

# %%
# Method to return a list of all keys 

d.keys()
# Out:
# dict_keys(['k1', 'k2', 'k3'])

# %%
# Method to grab all values
d.values()
# Out:
# dict_values([1, 2, 3])

# %%
# Method to return tuples of all items  (we'll learn about tuples soon)

d.items()
# Out:
# dict_items([('k1', 1), ('k2', 2), ('k3', 3)])

# %% [markdown]
# ### Example
#
# Create a dictionary and take input from the user and return the meaning of the word from the dictionary

# %%
d={'name':'bob','age':20,"gender":"male","eduaction":"msc"}

# %%
name=input("enter details: ")
print(d[name])
# Out:
# enter details: name
# bob

# %%
Dict = {"national animal":"tiger","National Bird":"Peacock","National Game":"Hockey"}
print("Enter the Word")
Data1 = input()
print(Data1, "is", Dict[Data1])
# Out:
# Enter the Word
# national animal
# national animal is tiger

# %% [markdown]
# ### USE CASES OF DICTIONARY
#
#
# # 1) RETURNING SINGLE ROW FROM dATBASE OR API
#
# row={
#     "id":101,
#     "name":"Jhon",
#     "country":"DE",
#     "Age":35,
#     "status":"Active"}
#
# ##### 1) RETURNED RECORDS ARE STORED AS DICTIONARIES WHERE COLUMN NAMES ARE KEYS AND THE ROW VALUES ARE DICTIONARY VALUES
# ##### 2) MAPPING TO FRIENDLY VALUES (GREAT FOR TECHINCAL CODES INTO FRIENDLY LABLES)
# ##### 3) mAPPING ABBREVIATIONS TURNING SHORT ABBRIVATION INTO FUILL NAMES
# ##### 4) STORING ENVIRONMENT VARIABLES AND CONFIGURATION
# ##### 5) etL AND PIPELINE SETTINGS
# ##### 6) STORING AS METADATA

# %% [markdown]
# ![image.png](attachment:ef9b8502-2c00-402e-b37d-aad5998cb41e.png)
