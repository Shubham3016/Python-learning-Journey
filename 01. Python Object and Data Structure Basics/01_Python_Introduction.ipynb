# %% [markdown]
# # Module 01 - Python Introduction 🐍
#
# ## Python Masterclass 2026
#
# ### Learning Objectives
#
# - What is Programming?
# - What is Python?
# - Why Learn Python?
# - Install Python
# - Install VS Code
# - Install Jupyter Notebook
# - Hello World
# - Internal Working
# - Applications
# - Mini Project

# %% [markdown]
# ## What is Programming?
#
# Programming means giving instructions to a computer.
#
# ### ELI5
# Imagine you have a robot. The robot only does exactly what you tell it to do. Programming is writing those instructions.

# %%
print('Wake Up')
print('Brush Teeth')
print('Go To School')
# Out:
# Wake Up
# Brush Teeth
# Go To School

# %% [markdown]
# ## What is Python?
#
# Python is an easy-to-read programming language created by Guido van Rossum in 1991.

# %%
import sys
print(sys.version)
# Out:
# 3.14.6 (tags/v3.14.6:c63aec6, Jun 10 2026, 10:26:10) [MSC v.1944 64 bit (AMD64)]

# %% [markdown]
# ## Why Learn Python?
#
# Python is used in AI, Data Science, Automation, Data Engineering, Web Development and more.

# %% [markdown]
# ## Install Python
#
# Download from https://python.org and check 'Add Python to PATH'.

# %% [markdown]
# ## Install Jupyter Notebook
#
# Run the following command in a terminal.

# %%
pip install notebook

# %% [markdown]
# ## Hello World
#
# Your first Python program.

# %%
print('Hello, World!')

# %% [markdown]
# ## How Python Works Internally
#
#
# ```
# Source Code
#      ↓
# Lexer
#      ↓
# Parser
#      ↓
# Bytecode
#      ↓
# Python Virtual Machine
#      ↓
# CPU
#      ↓
# Output
# ```

# %% [markdown]
# ## Applications of Python
#
# - AI
# - Machine Learning
# - Data Engineering
# - Automation
# - Web Development
# - Cyber Security

# %% [markdown]
# ## Mini Project
#
# Student Information Program

# %%
name=input("Name: ")
age=input("Age: ")
print("\nStudent Details")
print(name)
print(age)
# Out:
# Name:  bob
# Age:  26
# Student Details
# bob
# 26
